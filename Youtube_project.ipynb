# %%
pip install --upgrade google-api-python-client
# Out:
# ...
#
# ...

# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
def Api_Connect():
    api_id="AIzaSyASwUCm2xlBrhaoWTdyoY_hzjiY6P3fcTE"
    api_service_name="youtube"
    api_version="v3"
    youtube=build(api_service_name,api_version,developerKey=api_id)
    return youtube
youtube=Api_Connect()

# %%
#get channels information
def get_channel_info(channel_id):
    request =youtube.channels().list(
        part="snippet,ContentDetails,statistics",
        id=channel_id
    )
    response=request.execute()

    for i in response["items"]:
        data=dict(
                Channel_Name=i["snippet"]["title"],
                Channel_Id=i["id"],
                Subscription_Count=i["statistics"]["subscriberCount"],
                Channel_Views=i["statistics"]["viewCount"],
                Total_views=i["statistics"]["videoCount"],
                Channel_Description=i["snippet"]['description'],
                Playlist_Id=i["contentDetails"]['relatedPlaylists']['uploads']
                )
    return data

# %%
channel_details=get_channel_info("UCduIoIMfD8tT3KoU0-zBRgQ")

# %%
print(channel_details)
# Out:
# {'Channel_Name': 'GUVI', 'Channel_Id': 'UCduIoIMfD8tT3KoU0-zBRgQ', 'Subscription_Count': '210000', 'Channel_Views': '3935171', 'Total_views': '1431', 'Channel_Description': 'GUVI is an IIT-M & IIM-A incubated edu-tech company that offers Wide range of online Tech courses in your Native language.\nWith 100% placement support, Globally recognized certifications, Mentors from top global product companies  and Platforms improve your Programming and IT skills GUVI does it all. With over 18 Lakh+ learners and 9+ years of experience we provide apex learning through our Edu-tech services, GUVI shares its most loved Tech-videos on YouTube!\n\nWhat’s on our YouTube Channel?\nCareer guidance videos that give an idea for beginners & early professionals to upgrade their careers.\nNew initiatives & offers that unlock your flexible path for learning the latest technologies.\nWalkthrough videos of our practice platforms that shape up your coding & web development skills.\n\nKnow more by visiting our
# ...

# %%
#get video_ids information

def get_video_ids(channel_id):
    video_ids=[]

    response=youtube.channels().list(id=channel_id,part='contentDetails').execute()
    Playlist_Id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    next_page_token=None
    while True:
        response1=youtube.playlistItems().list(
            part='snippet',
            playlistId=Playlist_Id,
            maxResults=50,
            pageToken=next_page_token
        ).execute()
        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token=response1.get('nextPageToken')

        if next_page_token is None:
            break
    return video_ids

# %%
# video_ids=get_video_ids("UCduIoIMfD8tT3KoU0-zBRgQ")

# %%
# len(video_ids)

# %%
#get video information
def get_video_info(video_ids):
    video_data=[]
    for video_id in video_ids:
        request =youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=video_id
        )
        response=request.execute()
        for item in response["items"]:
            data=dict(Channel_Name=item['snippet']['channelTitle'],
                    Channel_Id=item['snippet']['channelId'],
                    Video_Id=item['id'],
                    Video_Name=item['snippet']['title'],
                    Video_Description=item['snippet'].get('description',[]),
                    Tags=item['snippet'].get('tags',[]),
                    PublishedAt=item['snippet']['publishedAt'],
                    Thumbnail=item['snippet']['thumbnails'],
                    Duration=item['contentDetails']['duration'],
                    View_Count=item['statistics']['viewCount'],
                    Like_Count=item['statistics']['likeCount'],
                    Favorite_Count=item['statistics']['favoriteCount'],
                    Comment_Count=item['statistics'].get('commentCount',[]),
                    Caption_Status=item['contentDetails']['caption'],
                    )
            video_data.append(data)
    return video_data

# %%
video_details=get_video_info(video_ids)

# %%
video_details
# Out:
# [{'Channel_Name': 'GUVI',
#   'Channel_Id': 'UCduIoIMfD8tT3KoU0-zBRgQ',
#   'Video_Id': '4OJL4EpF5tY',
#   'Video_Name': "GUVI's Top 10 Tech News | ChatGPT | Modi | Tesla | AI | Top 10 Tech News | GUVI",
# ...

# %%
df1=pd.DataFrame(video_data)
df1.head(10)
# Out:
#   Channel_Name                Channel_Id     Video_Id  \
# 0         GUVI  UCduIoIMfD8tT3KoU0-zBRgQ  4OJL4EpF5tY
# 1         GUVI  UCduIoIMfD8tT3KoU0-zBRgQ  mnT4B7Kj9wo
# 2         GUVI  UCduIoIMfD8tT3KoU0-zBRgQ  3o5TB9xl3uk
# 3         GUVI  UCduIoIMfD8tT3KoU0-zBRgQ  WillnkTSp6w
# 4         GUVI  UCduIoIMfD8tT3KoU0-zBRgQ  X3yuoAI9SnM
# 5         GUVI  UCduIoIMfD8tT3KoU0-zBRgQ  RlirXnTIByw
# 6         GUVI  UCduIoIMfD8tT3KoU0-zBRgQ  LZpXkLEU_ek
# 7         GUVI  UCduIoIMfD8tT3KoU0-zBRgQ  tpUmXxq0V9Q
# 8         GUVI  UCduIoIMfD8tT3KoU0-zBRgQ  sTHiUsGaeug
# 9         GUVI  UCduIoIMfD8tT3KoU0-zBRgQ  5E-GIPTpbYc
#
#                                           Video_Name  \
# 0  GUVI's Top 10 Tech News | ChatGPT | Modi | Tes...
# 1  Hey Cricket fans! Get a chance to watch IPL in...
# 2  Tamilnadu Coder's Premier League's Grand Final...
# 3  TNCPL: Tamilnadu's Largest AI 24hr Hackathon  ...
# 4  🤣🤣🤣🤣 | GUVI | #shortsvideo #guvi #shortsyoutub...
# ...

# %%
 #get comment information
def get_comment_info(video_ids):
    comment_data=[]
    try:
        for video_id in video_ids:
            request=youtube.commentThreads().list(
                part='snippet',
                videoId=video_id,
                maxResults=50
            )
            response=request.execute()
            for item in response['items']:
                data=dict(
                    Comment_Id=item['snippet'].get('topLevelComment', [])['id'],
                    Video_Id=item['snippet'].get('topLevelComment', []).get('snippet', []).get('videoId',[]),
                    Comment_Text=item['snippet'].get('topLevelComment', []).get('snippet', []).get("textDisplay",{}),
                    Comment_Author=item['snippet'].get('topLevelComment', []).get('snippet', []).get('authorDisplayName',[]),
                    Comment_Published_Date=item['snippet'].get('topLevelComment',[]).get('snippet', []).get('publishedAt', 'Default date or None')
                )
            comment_data.append(data)
    except:
        pass
    return comment_data

# %%
comment_details=get_comment_info(video_ids)

# %%
len(comment_details)
# Out:
# 0

# %%
# def get_playlist_details(channel_id):
#         next_page_token=None
#         All_data=[]
#         while True:
#                 request=youtube.playlists().list(
#                         part='snippet,contentDetails',
#                         channelId=channel_id,
#                         maxResults=50,
#                         pageToken=next_page_token
#                 )
#                 response=request.execute()

#                 for item in response['items']:
#                         data=dict(Playlist_Id=item['id'],
#                                 Title=item['snippet']['title'],
#                                 Channel_Id=item['snippet']['channelId'],
#                                 Channel_Name=item['snippet']['channelTitle'],
#                                 PublishedAt=item['snippet']['publishedAt'],
#                                 Video_Count=item['contentDetails']['itemCount'])
#                         All_data.append(data)

#                 next_page_token=response.get('nextPageToken')
#                 if next_page_token is None:
#                         break
#         return All_data

# %%
# playlist_details=get_playlist_details("UCduIoIMfD8tT3KoU0-zBRgQ")

# %%
# playlist_details
